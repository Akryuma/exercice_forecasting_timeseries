# %% [markdown]
# # Forecasting EURUSD

# %%
import os
if os.getcwd().split(os.sep)[-1] == "notebooks":
    os.chdir("..")

from data import retrieve_data

# %% [markdown]
# ## Data generation

# %%
df = retrieve_data("eurusd", "2024-11-01", "2024-11-10")
# Out:
# 'notebooks'
